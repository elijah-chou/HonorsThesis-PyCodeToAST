# %%
import pandas as pd
import numpy as np
import ast


with open("C:/Users/Elijah/Desktop/Python Sample Code.py", "r") as source:
    tmp = ast.parse(source.read())
ast.dump(tmp)
# Out:
# "Module(body=[Import(names=[alias(name='pandas', asname='pd')]), Import(names=[alias(name='numpy', asname='np')]), Import(names=[alias(name='seaborn', asname='sns')]), ImportFrom(module='scipy', names=[alias(name='stats', asname=None)], level=0), Assign(targets=[Name(id='data', ctx=Store())], value=Call(func=Attribute(value=Name(id='pd', ctx=Load()), attr='read_csv', ctx=Load()), args=[Constant(value='hw0_p1.csv', kind=None)], keywords=[]), type_comment=None), Expr(value=Call(func=Attribute(value=Name(id='data', ctx=Load()), attr='head', ctx=Load()), args=[], keywords=[])), Assign(targets=[Name(id='x1', ctx=Store())], value=Constant(value='x1', kind=None), type_comment=None), Assign(targets=[Name(id='xmin', ctx=Store())], value=Call(func=Attribute(value=Subscript(value=Name(id='data', ctx=Load()), slice=Index(value=Name(id='x1', ctx=Load())), ctx=Load()), attr='min', ctx=Load()), args=[], keywords=[]), type_comment=None), Assign(targets=[Name(id='xmax', ctx=Store())], value=Call(func
# ...
